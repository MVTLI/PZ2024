# %%
# %run "utils/sparkSes.ipynb"
# %run "utils/functions.ipynb"
# Out:
# Spark Session Created!
# Spark Context Created!
# Functions loaded!

# %%
from pyspark.sql.types import StructType, StringType, IntegerType, TimestampType

# schema = StructType() \
#     .add("id", IntegerType()) \
#     .add("name", StringType()) \
#     .add("timestamp", TimestampType()) 

schema = StructType() \
        .add("data", StringType())
keyword = "coffee"

api_urls = [
    f"https://dblp.org/search/publ/api?q={keyword}&format=json"
]

# Start stream
process_api_stream(api_urls, spark, schema, batch_interval=60)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |{hits={@computed=100, @total=552, hit=[{@id=56090, @score=2, url=URL#56090, info={ee=https://doi.org/10.1016/j.eswa.2023.121481, venue=Expert Syst. Appl., access=closed, year=2024, type=Journal Articles, title=CoffeeNet: A deep learning approach for coffee plant leaves diseases recognition., url=https://dblp.org/rec/journals/eswa/NawazNJAJT24, volume=237, number=Part B, pages=121481, key=journals/eswa/NawazNJAJT24, doi=10.1016/J.ESWA.2023.121481, authors={author=[{@pid=286/7961, text=Marriam Nawaz}, {@pid=252/1397, text=Tahira Nazir}, {@pid=182/0685, text=Ali Javed}, {@pid=123/9652, text=Sherif Tawfik Amin}, {@pid=227/4955, text=Fathe Jeribi}, {@pid=11/9457, text=Ali Tahir}]}}}, {@id=122210, @score=2, url=URL#122210, info={ee=https://doi.org/10.3390/rs16040728, venue=Remote. Sens., access=open, year=2024, type=Journal Articles, title=Use of Images Obtained by Remotely Piloted Aircraft and Random Forest for the Detection of Leaf Miner (Leucoptera coffeella) in Newly Planted Coffee Trees., url=https://dblp.org/rec/journals/remotesensing/SantosFBMRBC24, volume=16, number=4, pages=728, key=journals/remotesensing/SantosFBMRBC24, doi=10.3390/RS16040728, authors={author=[{@pid=282/9643, text=Luana Mendes dos Santos}, {@pid=282/8899, text=Gabriel Araújo e Silva Ferraz}, {@pid=370/0087, text=Nicole Lopes Bento}, {@pid=293/4110, text=Diego Bedin Marin}, {@pid=44/2140, text=Giuseppe Rossi}, {@pid=369/9904, text=Gianluca Bambi}, {@pid=282/9374, text=Leonardo Conti}]}}}, {@id=195870, @score=2, url=URL#195870, info={ee=https://doi.org/10.1145/3613905.3651030, venue=CHI Extended Abstracts, access=closed, pages=66:1-66:7, year=2024, type=Conference and Workshop Papers, title=CO-Coffee: A Technology Probe Study to Facilitate Coffee Breaks in Open Offices., url=https://dblp.org/rec/conf/chi/SunWZWLR24, key=conf/chi/SunWZWLR24, doi=10.1145/3613905.3651030, authors={author=[{@pid=37/9540, text=Xiaoqing Sun}, {@pid=18/3178, text=Jingyi Wang}, {@pid=60/5157, text=Yan Zhou}, {@pid=309/3482, text=Suhan Wang}, {@pid=144/6087, text=Yixuan Li}, {@pid=186/0288, text=Xipei Ren}]}}}, {@id=268463, @score=2, url=URL#268463, info={ee=https://doi.org/10.1145/3658271.3658289, venue=SBSI, access=closed, pages=18:1-18:10, year=2024, type=Conference and Workshop Papers, title=Quality Coffee Information Needs and Implications for Information Systems: a Study with Coffee Consumers., url=https://dblp.org/rec/conf/sbsi/MarquesMSF24, key=conf/sbsi/MarquesMSF24, doi=10.1145/3658271.3658289, authors={author=[{@pid=376/0067, text=Diego de Souza Marques}, {@pid=375/9844, text=Gabriela Silva Memento}, {@pid=146/6143, text=André de Lima Salgado}, {@pid=32/6218, text=André Pimenta Freire}]}}}, {@id=425155, @score=2, url=URL#425155, info={ee=https://doi.org/10.3390/data8120186, venue=Data, access=open, year=2023, type=Journal Articles, title=A Qualitative Dataset for Coffee Bio-Aggressors Detection Based on the Ancestral Knowledge of the Cauca Coffee Farmers in Colombia., url=https://dblp.org/rec/journals/data/ValenciaMosqueraGSFCC23, volume=8, number=12, pages=186, key=journals/data/ValenciaMosqueraGSFCC23, doi=10.3390/DATA8120186, authors={author=[{@pid=364/6555, text=Juan Felipe Valencia-Mosquera}, {@pid=69/3758, text=David Griol}, {@pid=364/6491, text=Mayra Solarte-Montoya}, {@pid=74/9569, text=Cristhian Figueroa}, {@pid=45/1368, text=Juan Carlos Corrales}, {@pid=163/9148, text=David Camilo Corrales}]}}}, {@id=516919, @score=2, url=URL#516919, info={ee=https://doi.org/10.3390/rs15010282, venue=Remote. Sens., access=open, year=2023, type=Journal Articles, title=Feasibility of Early Yield Prediction per Coffee Tree Based on Multispectral Aerial Imagery: Case of Arabica Coffee Crops in Cauca-Colombia., url=https://dblp.org/rec/journals/remotesensing/BolanosCC23, volume=15, number=1, pages=282, key=journals/remotesensing/BolanosCC23, doi=10.3390/RS15010282, authors={author=[{@pid=339/2586, text=Julian Bolaños}, {@pid=45/1368, text=Juan Carlos Corrales}, {@pid=262/8208, text=L ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
spark.sql("SHOW DATABASES").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
sc.stop()
